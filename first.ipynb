# %%
print("hello world")
# Out:
# hello world

# %%
print(1)
# Out:
# 1

# %%
type("data collection")
# Out:
# str

# %% [raw]
# data collection.upper()

# %%
data collection.lower()
# Out:
#   Cell In[5], line 1
#     data collection.lower()
#          ^
# SyntaxError: invalid syntax

# %%
"data collection".upper()
# Out:
# 'DATA COLLECTION'

# %%
"data collection".title
# Out:
# <function str.title()>

# %%
"data collection".title()
# Out:
# 'Data Collection'

# %%
list=[india, optional, canada, assam, china]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 list=[india, optional, canada, assam, china]
#
# NameError: name 'india' is not defined

# %%
"data collection".count('l')
# Out:
# 2

# %%
"data collection".count('b')

# %%
k="data collection".count('l')+"data collection".count('a')
print(k)
# Out:
# 4

# %%
"data collection".count('l')
# Out:
# 2

# %%
"data collection".replace('l', 'i')
# Out:
# 'data coiiection'

# %%
import pandas as pd

# %%
import numpy as np

# %%
data=np.array([[1,4],[2,4],[3,6]])

# %%
data
# Out:
# array([[1, 4],
#        [2, 4],
#        [3, 6]])

# %%
pd.DataFrame(data)
# Out:
#    0  1
# 0  1  4
# 1  2  4
# 2  3  6

# %%
df=pd.DataFrame(data, index=['R1', 'R2', 'R3'], columns=['C1', 'C2'])

# %%
df
# Out:
#     C1  C2
# R1   1   4
# R2   2   4
# R3   3   6

# %%
states=['kar', 'telen', 'goa']
popn=[396,297,219]

# %%
dict_states= {'States':states, 'population':popn}

# %%
states
# Out:
# ['kar', 'telen', 'goa']

# %%
popn
# Out:
# [396, 297, 219]

# %%
dict_states
# Out:
# {'States': ['kar', 'telen', 'goa'], 'population': [396, 297, 219]}

# %%
pd.DataFrame(dict_states)
# Out:
#   States  population
# 0    kar         396
# 1  telen         297
# 2    goa         219

# %%
df_dict=pd.DataFrame(dict_states)

# %%
df_dict
# Out:
#   States  population
# 0    kar         396
# 1  telen         297
# 2    goa         219

# %%
df_dict=pd.DataFrame(dict_states, index=['R1','R2','R3'])

# %%
df_dict
# Out:
#    States  population
# R1    kar         396
# R2  telen         297
# R3    goa         219

# %%
df_exams=pd.read_csv('Student_performance_data.csv')

# %%
df_exams
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
df_exams(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df_exams(5)
#
# TypeError: 'DataFrame' object is not callable

# %%
df_exams(head)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df_exams(head)
#
# NameError: name 'head' is not defined

# %%
df_exams.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
df_exams.tail()
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
#       Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 2387         2         0                4                1       0      0
# 2388         4         1                4                0       1      0
# 2389        20         0                2                0       0      0
# 2390        17         0                2                0       1      1
# 2391        13         0                2                0       0      0
#
#       Volunteering       GPA  GradeClass
# ...

# %%
df_exams.head(10)
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
# 5       1006   18       0          0                  1         8.191219
# 6       1007   15       0          1                  1        15.601680
# 7       1008   15       1          1                  4        15.424496
# 8       1009   17       0          0                  0         4.562008
# 9       1010   16       1          0                  1        18.444466
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# ...

# %%
df_exams.tail(25)
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 2367       3368   15       1          3                  1         9.381207
# 2368       3369   15       0          0                  4         6.682728
# 2369       3370   16       0          3                  3         2.147222
# 2370       3371   18       1          2                  1         2.912575
# 2371       3372   18       1          0                  3         0.668760
# 2372       3373   18       0          1                  2         9.404982
# 2373       3374   18       0          3                  2        19.088954
# 2374       3375   16       0          2                  1         2.313504
# 2375       3376   18       0          0                  2        18.925290
# 2376       3377   17       1          2                  2        14.667230
# 2377       3378   18       0          0                  2        12.749976
# ...

# %%
df_exams.shape
# Out:
# (2392, 15)

# %%
pd.set_option('display.max_rows',1000)

# %%
df_exams
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
df_exams
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
-exams
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 -exams
#
# NameError: name 'exams' is not defined

# %%
df_exams.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_exams.columns
#
# NameError: name 'df_exams' is not defined

# %%
df_exams.shape
# Out:
# (2392, 15)

# %%
df_exams.index
# Out:
# RangeIndex(start=0, stop=2392, step=1)

# %%
df_exams.dtypes
# Out:
# StudentID              int64
# Age                    int64
# Gender                 int64
# Ethnicity              int64
# ParentalEducation      int64
# StudyTimeWeekly      float64
# Absences               int64
# Tutoring               int64
# ParentalSupport        int64
# Extracurricular        int64
# Sports                 int64
# Music                  int64
# Volunteering           int64
# GPA                  float64
# GradeClass           float64
# dtype: object

# %%
df_exams.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
df_exmas.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df_exmas.info()
#
# NameError: name 'df_exmas' is not defined

# %%
df_exmas.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df_exmas.info()
#
# NameError: name 'df_exmas' is not defined

# %%
df_exams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB

# %%
df_exams.describe()
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# ...

# %%
len(df_exams)
# Out:
# 2392

# %%
max(df_exams)
# Out:
# 'Volunteering'

# %%
min(df_exams)
# Out:
# 'Absences'

# %%
df_exams.max()
# Out:
# StudentID            3392.000000
# Age                    18.000000
# Gender                  1.000000
# Ethnicity               3.000000
# ParentalEducation       4.000000
# StudyTimeWeekly        19.978094
# Absences               29.000000
# Tutoring                1.000000
# ParentalSupport         4.000000
# Extracurricular         1.000000
# Sports                  1.000000
# Music                   1.000000
# Volunteering            1.000000
# GPA                     4.000000
# GradeClass              4.000000
# dtype: float64

# %%
max(df_exams)
# Out:
# 'Volunteering'

# %%
max(df_exams.index)
# Out:
# 2391

# %%
min(df_exams.index)
# Out:
# 0

# %%
type(df_exams.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
df_exams.type()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_exams.type()
#
# NameError: name 'df_exams' is not defined

# %%
df_exams.type

# %%
type(df_exams)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 type(df_exams)
#
# NameError: name 'df_exams' is not defined

# %%
df_exams.shape
# Out:
# (2392, 15)

# %%
df_exams.index
# Out:
# RangeIndex(start=0, stop=2392, step=1)

# %%
len(df_exams)
# Out:
# 2392

# %%
max(df_exams.index)
# Out:
# 2391

# %%
df_exams['StudentID']
# Out:
# 0       1001
# 1       1002
# 2       1003
# 3       1004
# 4       1005
#         ...
# 2387    3388
# 2388    3389
# 2389    3390
# 2390    3391
# 2391    3392
# Name: StudentID, Length: 2392, dtype: int64

# %%
type(df_exams)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df_exams['StudentID'])
# Out:
# pandas.core.series.Series

# %%
df_exams[['StudentID']]
# Out:
#       StudentID
# 0          1001
# 1          1002
# 2          1003
# 3          1004
# 4          1005
# ...         ...
# 2387       3388
# 2388       3389
# 2389       3390
# 2390       3391
# 2391       3392
#
# [2392 rows x 1 columns]

# %%
type(df_exams[['StudentID']])
# Out:
# pandas.core.frame.DataFrame

# %%
df_exams.StudentID
# Out:
# 0       1001
# 1       1002
# 2       1003
# 3       1004
# 4       1005
#         ...
# 2387    3388
# 2388    3389
# 2389    3390
# 2390    3391
# 2391    3392
# Name: StudentID, Length: 2392, dtype: int64

# %%
type(df_exams.StudentID)
# Out:
# pandas.core.series.Series

# %%
df_exams['StudentID']
# Out:
# 0       1001
# 1       1002
# 2       1003
# 3       1004
# 4       1005
#         ...
# 2387    3388
# 2388    3389
# 2389    3390
# 2390    3391
# 2391    3392
# Name: StudentID, Length: 2392, dtype: int64

# %%
type(df_exams['StudentID'])
# Out:
# pandas.core.series.Series

# %%
df_exams['GPA1']=7

# %%
df_exams
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
import numpy as np

# %%
np.arange(0,2392)
# Out:
# array([   0,    1,    2, ..., 2389, 2390, 2391])

# %%
GPA2=np.arange(0,2392)

# %%
df_exams
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
df_exams['GPA2']=GPA2

# %%
df_exams
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
df_exams['new']=GPA2

# %%
df_exams
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
np.random.randint(1,10,size=2392)
# Out:
# array([6, 5, 4, ..., 9, 3, 2])

# %%
GPA3=np.random.randint(1,10,size=2392)

# %%
len(GPA3)
# Out:
# 2392

# %%
min(GPA3)
# Out:
# 1

# %%
max(GPA3)
# Out:
# 9

# %%
df_exams['GPA3']=GPA3

# %%
df_exams
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
GPA4=np.random.uniform(1,10,2392)

# %%
df_exams['GPA4']=GPA4

# %%
df_exams
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
df_exams.GPA4
# Out:
# 0       9.161663
# 1       2.152242
# 2       5.024316
# 3       3.734964
# 4       2.022508
#           ...
# 2387    4.352382
# 2388    8.611757
# 2389    4.930699
# 2390    4.445133
# 2391    7.067473
# Name: GPA4, Length: 2392, dtype: float64

# %%
type(df_exams.GPA4)
# Out:
# pandas.core.series.Series

# %%
df_exams['GPA4']
# Out:
# 0       9.161663
# 1       2.152242
# 2       5.024316
# 3       3.734964
# 4       2.022508
#           ...
# 2387    4.352382
# 2388    8.611757
# 2389    4.930699
# 2390    4.445133
# 2391    7.067473
# Name: GPA4, Length: 2392, dtype: float64

# %%
type(df_exams['GPA4'])
# Out:
# pandas.core.series.Series

# %%
df_exams[['GPA3', 'GPA4']]
# Out:
#       GPA3      GPA4
# 0        5  9.161663
# 1        1  2.152242
# 2        8  5.024316
# 3        8  3.734964
# 4        3  2.022508
# ...    ...       ...
# 2387     3  4.352382
# 2388     6  8.611757
# 2389     4  4.930699
# 2390     3  4.445133
# 2391     2  7.067473
#
# [2392 rows x 2 columns]

# %%
type(df_exams[['GPA3', 'GPA4']])
# Out:
# pandas.core.frame.DataFrame

# %%
GPA3=np.random.randint(1,10,size=2392)

# %%
GPA4=np.random.randint(1,10,size=2392)

# %%
series1=pd.Series(GPA3,index=np.arange(0,2392))

# %%
series2=pd.Series(GPA4, index=np.arange(0,2392))

# %%
df_exams.assign(GPA3=series1, GPA4=series2)
# Out:
#       StudentID  test  Age  Gender  Ethnicity  ParentalEducation  \
# 0          1001     5   17       1          0                  2
# 1          1002     3   18       0          0                  1
# 2          1003     5   15       0          2                  3
# 3          1004     2   17       1          0                  3
# 4          1005     2   17       1          0                  2
# ...         ...   ...  ...     ...        ...                ...
# 2387       3388     7   18       1          0                  3
# 2388       3389     8   17       0          0                  1
# 2389       3390     3   16       1          0                  2
# 2390       3391     3   16       1          1                  0
# 2391       3392     7   16       1          0                  2
#
#       StudyTimeWeekly  Absences  Tutoring  ParentalSupport  ...  Volunteering  \
# 0           19.833723         7         1                2  ...             0
# ...

# %%
df_exams=df_exams.assign(GPA3=series1, GPA4=series2)

# %%
df_exams
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
df_exams.insert(1,'test',series1)

# %%
df_exams
# Out:
#       StudentID  test  Age  Gender  Ethnicity  ParentalEducation  \
# 0          1001     5   17       1          0                  2
# 1          1002     3   18       0          0                  1
# 2          1003     5   15       0          2                  3
# 3          1004     2   17       1          0                  3
# 4          1005     2   17       1          0                  2
# ...         ...   ...  ...     ...        ...                ...
# 2387       3388     7   18       1          0                  3
# 2388       3389     8   17       0          0                  1
# 2389       3390     3   16       1          0                  2
# 2390       3391     3   16       1          1                  0
# 2391       3392     7   16       1          0                  2
#
#       StudyTimeWeekly  Absences  Tutoring  ParentalSupport  ...  Volunteering  \
# 0           19.833723         7         1                2  ...             0
# ...

# %%
df_exams['average']=(df_exams['GPA2']+df_exams['GPA3']+df_exams['GPA4'])/3

# %%
df_exams
# Out:
#       StudentID  test  Age  Gender  Ethnicity  ParentalEducation  \
# 0          1001     5   17       1          0                  2
# 1          1002     3   18       0          0                  1
# 2          1003     5   15       0          2                  3
# 3          1004     2   17       1          0                  3
# 4          1005     2   17       1          0                  2
# ...         ...   ...  ...     ...        ...                ...
# 2387       3388     7   18       1          0                  3
# 2388       3389     8   17       0          0                  1
# 2389       3390     3   16       1          0                  2
# 2390       3391     3   16       1          1                  0
# 2391       3392     7   16       1          0                  2
#
#       StudyTimeWeekly  Absences  Tutoring  ParentalSupport  ...       GPA  \
# 0           19.833723         7         1                2  ...  2.929196
# ...

# %%
import pyodide_http
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import pyodide_http
#
# ModuleNotFoundError: No module named 'pyodide_http'

# %%
pyodide_https.patch_all()

# %%
import pandas as pd

# %%
df_p21=pd.read_csv('E0.csv')
# https://football-data.co.uk/mmz4281/2122/E0.csv

# %%
import pandas as pd

# %%
df_p21.head()
# Out:
#   Div        Date   Time     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  15/08/2025  20:00    Liverpool  Bournemouth     4     2   H     1
# 1  E0  16/08/2025  12:30  Aston Villa    Newcastle     0     0   D     0
# 2  E0  16/08/2025  15:00     Brighton       Fulham     1     1   D     0
# 3  E0  16/08/2025  15:00   Sunderland     West Ham     3     0   H     0
# 4  E0  16/08/2025  15:00    Tottenham      Burnley     3     0   H     1
#
#    HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 0     0  ...     2.03     1.78   2.07   1.85     2.03     1.88     1.94
# 1     0  ...     2.05     1.80   2.02   1.89     2.06     1.80     1.95
# 2     0  ...     1.83     2.03   1.93   2.00     1.84     2.03     1.80
# 3     0  ...     1.95     1.90   1.97   1.95     1.95     1.94     1.86
# 4     0  ...     1.98     1.88   1.99   1.93     1.98     1.91     1.88
#
#    AvgCAHA  BFECAHH  BFECAHA
# 0     1.76     2.14     1.86
# 1     1.74     2.14     1.86
# ...

# %%
df_exams=pd.read_csv('Student_performance_data.csv')

# %%
df_exams
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
df_p21=pd.read_csv('E0.csv')
df_p21.head()
# Out:
#   Div        Date   Time     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  15/08/2025  20:00    Liverpool  Bournemouth     4     2   H     1
# 1  E0  16/08/2025  12:30  Aston Villa    Newcastle     0     0   D     0
# 2  E0  16/08/2025  15:00     Brighton       Fulham     1     1   D     0
# 3  E0  16/08/2025  15:00   Sunderland     West Ham     3     0   H     0
# 4  E0  16/08/2025  15:00    Tottenham      Burnley     3     0   H     1
#
#    HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 0     0  ...     2.03     1.78   2.07   1.85     2.03     1.88     1.94
# 1     0  ...     2.05     1.80   2.02   1.89     2.06     1.80     1.95
# 2     0  ...     1.83     2.03   1.93   2.00     1.84     2.03     1.80
# 3     0  ...     1.95     1.90   1.97   1.95     1.95     1.94     1.86
# 4     0  ...     1.98     1.88   1.99   1.93     1.98     1.91     1.88
#
#    AvgCAHA  BFECAHH  BFECAHA
# 0     1.76     2.14     1.86
# 1     1.74     2.14     1.86
# ...

# %%
df_p21
# Out:
#    Div        Date   Time     HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0   E0  15/08/2025  20:00    Liverpool     Bournemouth     4     2   H     1
# 1   E0  16/08/2025  12:30  Aston Villa       Newcastle     0     0   D     0
# 2   E0  16/08/2025  15:00     Brighton          Fulham     1     1   D     0
# 3   E0  16/08/2025  15:00   Sunderland        West Ham     3     0   H     0
# 4   E0  16/08/2025  15:00    Tottenham         Burnley     3     0   H     1
# ..  ..         ...    ...          ...             ...   ...   ...  ..   ...
# 85  E0  26/10/2025  14:00      Arsenal  Crystal Palace     1     0   H     1
# 86  E0  26/10/2025  14:00  Aston Villa        Man City     1     0   H     1
# 87  E0  26/10/2025  14:00  Bournemouth   Nott'm Forest     2     0   H     2
# 88  E0  26/10/2025  14:00       Wolves         Burnley     2     3   A     2
# 89  E0  26/10/2025  16:30      Everton       Tottenham     0     3   A     0
#
# ...

# %%
df_p21.rename(columns={'FTHG':'home_goals','FTAG':'away_goals'},inplace=True)

# %%
df_p21
# Out:
#    Div        Date   Time     HomeTeam        AwayTeam  home_goals  \
# 0   E0  15/08/2025  20:00    Liverpool     Bournemouth           4
# 1   E0  16/08/2025  12:30  Aston Villa       Newcastle           0
# 2   E0  16/08/2025  15:00     Brighton          Fulham           1
# 3   E0  16/08/2025  15:00   Sunderland        West Ham           3
# 4   E0  16/08/2025  15:00    Tottenham         Burnley           3
# ..  ..         ...    ...          ...             ...         ...
# 85  E0  26/10/2025  14:00      Arsenal  Crystal Palace           1
# 86  E0  26/10/2025  14:00  Aston Villa        Man City           1
# 87  E0  26/10/2025  14:00  Bournemouth   Nott'm Forest           2
# 88  E0  26/10/2025  14:00       Wolves         Burnley           2
# 89  E0  26/10/2025  16:30      Everton       Tottenham           0
#
#     away_goals FTR  HTHG  HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0            2   H     1     0  ...     2.03     1.78   2.07   1.85     2.03
# ...

# %%
1==2
# Out:
# False

# %%
df_p21['HomeTeam']=='Aston Villa'
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
#       ...
# 85    False
# 86     True
# 87    False
# 88    False
# 89    False
# Name: HomeTeam, Length: 90, dtype: bool

# %%
df_p22=c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df_p22=c
#
# NameError: name 'c' is not defined

# %%
df_p22
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df_p22
#
# NameError: name 'df_p22' is not defined

# %%
df_p21['HomeTeam'].value_counts()
# Out:
# HomeTeam
# Newcastle         5
# Brentford         5
# Everton           5
# Wolves            5
# Chelsea           5
# Arsenal           5
# Man United        5
# Leeds             5
# Aston Villa       5
# Bournemouth       5
# Fulham            4
# Crystal Palace    4
# Burnley           4
# Liverpool         4
# Man City          4
# Nott'm Forest     4
# Tottenham         4
# Sunderland        4
# Brighton          4
# West Ham          4
# Name: count, dtype: int64

# %%
df_p22.shape
# Out:
# (5, 132)

# %%
df_p21[df_p21['HomeTeam']=='Aston Villa'].value_counts('HomeTeam')
# Out:
# HomeTeam
# Aston Villa    5
# Name: count, dtype: int64

# %% [markdown]
# df_p21[df

# %%
df_p21[df_p21['HomeTeam'].ne('Aston Villa')].value_counts('HomeTeam')
# Out:
# HomeTeam
# Arsenal           5
# Everton           5
# Newcastle         5
# Man United        5
# Bournemouth       5
# Leeds             5
# Chelsea           5
# Brentford         5
# Wolves            5
# Crystal Palace    4
# Fulham            4
# Burnley           4
# Liverpool         4
# Man City          4
# Brighton          4
# Nott'm Forest     4
# Sunderland        4
# Tottenham         4
# West Ham          4
# Name: count, dtype: int64

# %%
df_p21[df_p21['HomeTeam']!=('Aston Villa')]
# Out:
#    Div        Date   Time     HomeTeam        AwayTeam  home_goals  \
# 0   E0  15/08/2025  20:00    Liverpool     Bournemouth           4
# 2   E0  16/08/2025  15:00     Brighton          Fulham           1
# 3   E0  16/08/2025  15:00   Sunderland        West Ham           3
# 4   E0  16/08/2025  15:00    Tottenham         Burnley           3
# 5   E0  16/08/2025  17:30       Wolves        Man City           0
# ..  ..         ...    ...          ...             ...         ...
# 84  E0  25/10/2025  20:00    Brentford       Liverpool           3
# 85  E0  26/10/2025  14:00      Arsenal  Crystal Palace           1
# 87  E0  26/10/2025  14:00  Bournemouth   Nott'm Forest           2
# 88  E0  26/10/2025  14:00       Wolves         Burnley           2
# 89  E0  26/10/2025  16:30      Everton       Tottenham           0
#
#     away_goals FTR  HTHG  HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0            2   H     1     0  ...     2.03     1.78   2.07   1.85     2.03
# ...

# %%
df_p21[df_p21['home_goals']>= 4]
# Out:
#    Div        Date   Time    HomeTeam     AwayTeam  home_goals  away_goals  \
# 0   E0  15/08/2025  20:00   Liverpool  Bournemouth           4           2
# 15  E0  23/08/2025  17:30     Arsenal        Leeds           5           0
# 54  E0  27/09/2025  15:00    Man City      Burnley           5           1
# 83  E0  25/10/2025  17:30  Man United     Brighton           4           2
#
#    FTR  HTHG  HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  \
# 0    H     1     0  ...     2.03     1.78   2.07   1.85     2.03     1.88
# 15   H     2     0  ...     2.00     1.85   2.04   1.88     2.00     1.91
# 54   H     1     1  ...     1.95     1.90   2.03   1.88     1.95     1.98
# 83   H     2     0  ...     1.98     1.88   2.04   1.88     2.00     1.88
#
#     AvgCAHH  AvgCAHA  BFECAHH  BFECAHA
# 0      1.94     1.76     2.14     1.86
# 15     1.91     1.85     2.06     1.92
# 54     1.88     1.89     2.05     1.92
# 83     1.95     1.82     2.08     1.91
#
# ...

# %%
df_p21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Columns: 132 entries, Div to BFECAHA
# dtypes: float64(108), int64(16), object(8)
# memory usage: 92.9+ KB

# %%
import numpy as np

# %%
df_p21['class']=np.where(df_p21['home_goals'] >=4, 'Good', 'Average')

# %%
df_p21['home_goals'] >= 4
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 85    False
# 86    False
# 87    False
# 88    False
# 89    False
# Name: home_goals, Length: 90, dtype: bool

# %% [markdown]
# #

# %%
df_p21[df_p21['home_goals'] >= 4]
# Out:
#    Div        Date   Time    HomeTeam     AwayTeam  home_goals  away_goals  \
# 0   E0  15/08/2025  20:00   Liverpool  Bournemouth           4           2
# 15  E0  23/08/2025  17:30     Arsenal        Leeds           5           0
# 54  E0  27/09/2025  15:00    Man City      Burnley           5           1
# 83  E0  25/10/2025  17:30  Man United     Brighton           4           2
#
#    FTR  HTHG  HTAG  ... B365CAHA PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 0    H     1     0  ...     1.78  2.07   1.85     2.03     1.88     1.94
# 15   H     2     0  ...     1.85  2.04   1.88     2.00     1.91     1.91
# 54   H     1     1  ...     1.90  2.03   1.88     1.95     1.98     1.88
# 83   H     2     0  ...     1.88  2.04   1.88     2.00     1.88     1.95
#
#     AvgCAHA  BFECAHH  BFECAHA  class
# 0      1.76     2.14     1.86   Good
# 15     1.85     2.06     1.92   Good
# 54     1.89     2.05     1.92   Good
# 83     1.82     2.08     1.91   Good
#
# [4 rows x 133 columns]

# %%
df_p21['class'].value_counts()
# Out:
# class
# Average    86
# Good        4
# Name: count, dtype: int64

# %%
df_p21['away_goals']>1
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 85    False
# 86    False
# 87    False
# 88     True
# 89     True
# Name: away_goals, Length: 90, dtype: bool

# %%
df_p21[df_p21['away_goals'] > 1]
# Out:
#    Div        Date   Time        HomeTeam        AwayTeam  home_goals  \
# 0   E0  15/08/2025  20:00       Liverpool     Bournemouth           4
# 5   E0  16/08/2025  17:30          Wolves        Man City           0
# 10  E0  22/08/2025  20:00        West Ham         Chelsea           1
# 11  E0  23/08/2025  12:30        Man City       Tottenham           0
# 19  E0  25/08/2025  20:00       Newcastle       Liverpool           2
# 21  E0  30/08/2025  15:00      Man United         Burnley           3
# 24  E0  30/08/2025  15:00          Wolves         Everton           2
# 27  E0  31/08/2025  14:00   Nott'm Forest        West Ham           0
# 29  E0  31/08/2025  19:00     Aston Villa  Crystal Palace           0
# 36  E0  13/09/2025  17:30        West Ham       Tottenham           0
# 37  E0  13/09/2025  20:00       Brentford         Chelsea           2
# 41  E0  20/09/2025  15:00        Brighton       Tottenham           2
# ...

# %%
np.where(df_p21['away_goals']>1, 'Big', 'Small')
# Out:
# array(['Big', 'Small', 'Small', 'Small', 'Small', 'Big', 'Small', 'Small',
#        'Small', 'Small', 'Big', 'Big', 'Small', 'Small', 'Small', 'Small',
#        'Small', 'Small', 'Small', 'Big', 'Small', 'Big', 'Small', 'Small',
#        'Big', 'Small', 'Small', 'Big', 'Small', 'Big', 'Small', 'Small',
#        'Small', 'Small', 'Small', 'Small', 'Big', 'Big', 'Small', 'Small',
#        'Small', 'Big', 'Small', 'Big', 'Big', 'Small', 'Small', 'Small',
#        'Small', 'Small', 'Small', 'Big', 'Small', 'Big', 'Small', 'Small',
#        'Small', 'Small', 'Big', 'Small', 'Small', 'Big', 'Small', 'Small',
#        'Small', 'Small', 'Small', 'Small', 'Small', 'Small', 'Big',
#        'Small', 'Small', 'Big', 'Small', 'Small', 'Small', 'Big', 'Big',
#        'Big', 'Small', 'Big', 'Small', 'Big', 'Big', 'Small', 'Small',
#        'Small', 'Big', 'Big'], dtype='<U5')

# %%
df_p21['awayclass']=np.where(df_p21['away_goals']>1,'Big', 'Small')

# %%
df_p21
# Out:
#    Div        Date   Time     HomeTeam        AwayTeam  home_goals  \
# 0   E0  15/08/2025  20:00    Liverpool     Bournemouth           4
# 1   E0  16/08/2025  12:30  Aston Villa       Newcastle           0
# 2   E0  16/08/2025  15:00     Brighton          Fulham           1
# 3   E0  16/08/2025  15:00   Sunderland        West Ham           3
# 4   E0  16/08/2025  15:00    Tottenham         Burnley           3
# ..  ..         ...    ...          ...             ...         ...
# 85  E0  26/10/2025  14:00      Arsenal  Crystal Palace           1
# 86  E0  26/10/2025  14:00  Aston Villa        Man City           1
# 87  E0  26/10/2025  14:00  Bournemouth   Nott'm Forest           2
# 88  E0  26/10/2025  14:00       Wolves         Burnley           2
# 89  E0  26/10/2025  16:30      Everton       Tottenham           0
#
#     away_goals FTR  HTHG  HTAG  ... PCAHH PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 0            2   H     1     0  ...  2.07  1.85     2.03     1.88     1.94
# ...

# %%
df_p21['away_goals'].value_counts()
# Out:
# away_goals
# 1    33
# 0    29
# 2    15
# 3    11
# 4     1
# 5     1
# Name: count, dtype: int64

# %%
df_p21['awayclass'].value_counts()
# Out:
# awayclass
# Small    62
# Big      28
# Name: count, dtype: int64

# %%
df_p21.head(5)
# Out:
#   Div        Date   Time     HomeTeam     AwayTeam  home_goals  away_goals  \
# 0  E0  15/08/2025  20:00    Liverpool  Bournemouth           4           2
# 1  E0  16/08/2025  12:30  Aston Villa    Newcastle           0           0
# 2  E0  16/08/2025  15:00     Brighton       Fulham           1           1
# 3  E0  16/08/2025  15:00   Sunderland     West Ham           3           0
# 4  E0  16/08/2025  15:00    Tottenham      Burnley           3           0
#
#   FTR  HTHG  HTAG  ... PCAHH PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  \
# 0   H     1     0  ...  2.07  1.85     2.03     1.88     1.94     1.76
# 1   D     0     0  ...  2.02  1.89     2.06     1.80     1.95     1.74
# 2   D     0     0  ...  1.93  2.00     1.84     2.03     1.80     1.96
# 3   H     0     0  ...  1.97  1.95     1.95     1.94     1.86     1.78
# 4   H     1     0  ...  1.99  1.93     1.98     1.91     1.88     1.83
#
#    BFECAHH  BFECAHA    class  awayclass
# 0     2.14     1.86     Good        Big
# ...

# %%
df_p21.value_counts('awayclass')
# Out:
# awayclass
# Small    62
# Big      28
# Name: count, dtype: int64

# %%
df_p21[(df_p21['class']=='Good') & (df_p21['awayclass']=='Big')]
# Out:
#    Div        Date   Time    HomeTeam     AwayTeam  home_goals  away_goals  \
# 0   E0  15/08/2025  20:00   Liverpool  Bournemouth           4           2
# 83  E0  25/10/2025  17:30  Man United     Brighton           4           2
#
#    FTR  HTHG  HTAG  ... PCAHH PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  \
# 0    H     1     0  ...  2.07  1.85     2.03     1.88     1.94     1.76
# 83   H     2     0  ...  2.04  1.88     2.00     1.88     1.95     1.82
#
#     BFECAHH  BFECAHA  class  awayclass
# 0      2.14     1.86   Good        Big
# 83     2.08     1.91   Good        Big
#
# [2 rows x 134 columns]

# %%
df_p21['logic']=np.where((df_p21['class']=='Good') & (df_p21['awayclass']=='Big'), True, False)

# %%
df_p21
# Out:
#    Div        Date   Time     HomeTeam        AwayTeam  home_goals  \
# 0   E0  15/08/2025  20:00    Liverpool     Bournemouth           4
# 1   E0  16/08/2025  12:30  Aston Villa       Newcastle           0
# 2   E0  16/08/2025  15:00     Brighton          Fulham           1
# 3   E0  16/08/2025  15:00   Sunderland        West Ham           3
# 4   E0  16/08/2025  15:00    Tottenham         Burnley           3
# ..  ..         ...    ...          ...             ...         ...
# 85  E0  26/10/2025  14:00      Arsenal  Crystal Palace           1
# 86  E0  26/10/2025  14:00  Aston Villa        Man City           1
# 87  E0  26/10/2025  14:00  Bournemouth   Nott'm Forest           2
# 88  E0  26/10/2025  14:00       Wolves         Burnley           2
# 89  E0  26/10/2025  16:30      Everton       Tottenham           0
#
#     away_goals FTR  HTHG  HTAG  ... PCAHA MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  \
# 0            2   H     1     0  ...  1.85    2.03     1.88     1.94     1.76
# ...

# %%
df_p21.value_counts('logic')
# Out:
# logic
# False    88
# True      2
# Name: count, dtype: int64

# %%
df_p21[df_p21['logic']==True]
# Out:
#    Div        Date   Time    HomeTeam     AwayTeam  home_goals  away_goals  \
# 0   E0  15/08/2025  20:00   Liverpool  Bournemouth           4           2
# 83  E0  25/10/2025  17:30  Man United     Brighton           4           2
#
#    FTR  HTHG  HTAG  ... PCAHA MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  BFECAHH  \
# 0    H     1     0  ...  1.85    2.03     1.88     1.94     1.76     2.14
# 83   H     2     0  ...  1.88    2.00     1.88     1.95     1.82     2.08
#
#     BFECAHA  class  awayclass  logic
# 0      1.86   Good        Big   True
# 83     1.91   Good        Big   True
#
# [2 rows x 135 columns]
